# %%
import pandas as pd

# %%
server_df = pd.read_csv('Chr10.server.fam', sep = ' ', header=None)

# %%
samples_server = server_df[1]

# %%
site_df = pd.read_csv('1000genomes_samples.tsv', sep='\t')

# %%
site_df.head()
# Out:
#   Sample name     Sex Biosample ID Population code Population name  \
# 0     HG00103    male   SAME125151             GBR         British
# 1     HG00108    male   SAME125161             GBR         British
# 2     HG00097  female   SAME123267             GBR         British
# 3     HG00110  female   SAME125339             GBR         British
# 4     HG00100  female   SAME125154             GBR         British
#
#   Superpopulation code Superpopulation name  \
# 0                  EUR             European
# 1                  EUR             European
# 2                  EUR             European
# 3                  EUR             European
# 4                  EUR             European
#
#                                     Data collections
# 0  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 1  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 2  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 3  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# ...

# %%
sum(samples_server.isin(site_df['Sample name']))
# Out:
# 503

# %%
missing_df = site_df[~site_df['Sample name'].isin(samples_server)]

# %%
missing_df[['Sample name','Data collections']]
# Out:
#     Sample name                                   Data collections
# 8       HG00098  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 21      HG00124  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 28      HG00303                             1000 Genomes on GRCh38
# 31      HG00249  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 38      HG00144  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 39      HG00153  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 49      HG00270  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 51      HG00134  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 54      HG00152  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 75      HG00247  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 88      HG00302                             1000 Genomes on GRCh38
# 111     HG00156  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# 123     HG00312  1000 Genomes on GRCh38,1000 Genomes phase 3 re...
# ...
